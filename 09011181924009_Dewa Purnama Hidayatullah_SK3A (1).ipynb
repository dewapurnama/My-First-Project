# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
df = pd.read_csv("uts.csv")

# %% [markdown]
# link dataset = https://www.kaggle.com/gregorut/videogamesales

# %% [markdown]
# # CHAPTER 1.1

# %%
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# Case : Video game sales
#
# Label : Label yang digunakan yaitu Name, karena Name merupakan variabel yang unik dan setiap data mempunyai nama yang berbeda.
#
# Variabel Kuantitatif : Rank, Year, NA_Sales, EU_Sales, JP_Sales, Other_Sales, Global_Sales
#
# Variabel Kategorikal : Name, Platform, Genre, Publisher
#
# Key Characteristic of data set
# 1. Who : Ada satu case, yaitu video game sales.
# 2. What : Ada 11 variabel yaitu Rank, Name, Platform, Year, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales, Global_Sales.
# 3. Why : Data set ini dibuat untuk menyajikan informasi mengenai penjualan video games.

# %% [markdown]
# # CHAPTER 1.2, 1.3, 1.4

# %%
df.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %% [markdown]
# Analisa:
#
# Dengan menggunakan df.describe(), kita bisa melihat pusat distribusi dari data set yang dimasukkan untuk setiap variabel kuantitatifnya. Seperti yang bisa dilihat diatas terdapat data berupa jumlah setiap variabel(count), rata-rata(mean), standar deviasi(std), nilai terkecil(min), kuartil bawah(25%), kuartil tengah/median(50%), kuartil atas(75%), dan nilai maksimum(max).
#
# Saya disini akan mengambil contoh variabel yaitu Year.
#
# Untuk Year sendiri mempunyai mean 2006 dan median 2007. Ini berarti bahwa untuk variabel Year, pusat distribusi atau penyebaran data nya berkisar di Tahun 2006 dan 2007.
#
# Kemudian data kuartil bisa digunakan untuk menentukan pencilan atau outliernya.
#
# IQR = Q3-Q1 = 2010-2003 = 7
#
# 1,5 x 7 = 1,5 x IQR = 1,5 x 7 = 10,5
#
# Q1 - (1,5 x IQR) = 2003 - 7 = 1994
#
# Q3 + (1,5 X 1QR) = 2010 + 7 = 2017
#
# Maka, bisa ditentukan bahwa outlier merupakan data yang berada di bawah 1994 atau di atas 2017

# %%
plt.hist(df["Year"])
# Out:
# (array([ 108.,   65.,   89.,  443., 1269., 2435., 3914., 5257., 2399.,
#          348.]),
#  array([1980., 1984., 1988., 1992., 1996., 2000., 2004., 2008., 2012.,
#         2016., 2020.]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# Analisis:
#
# Saya disini mengidentifikasi 2 variabel, Year(kuantitatif) dan Platform(Kategorikal). Untuk variabel kuantitatif, saya akan menggunakan histogram untuk melakukan analisa data dan untuk variabel kategorikal, saya akan menggunakan pie chart dan juga bar chart.
#
# Untuk variabel Year, five-number summary nya adalah sebagai berikut(dilihat dari df.decribe()):
# Minimum = 1980, Q1 = 2003, Median = 2007, Q3 = 2010, Maksimum = 2020
#
# Adapun IQR nya sebagai berikut:
# IQR = Q3-Q1 = 2010-2003 = 7
#
# 1,5 x 7 = 1,5 x IQR = 1,5 x 7 = 10,5
#
# Q1 - (1,5 x IQR) = 2003 - 7 = 1994
#
# Q3 + (1,5 X 1QR) = 2010 + 7 = 2017
#
# Maka, bisa ditentukan bahwa outlier merupakan data yang berada di bawah 1994 atau di atas 2017
#
# Distribusi dari histogram variabel Year di atas yaitu:
#
# Shape : Unimodal (dapat dilihat dengan hanya ada satu puncak) dan left-skewed (data semakin menurun ke sebelah kiri).
#
# Jika sebuah data berbentuk simetris dan tidak memiliki outlier, maka median dan kuartil akan lebih baik dan akurat digunakan untuk mengukur center dan spread. Akan tetapi, jika data berbentuk skewed atau tidak simetris dan memiiki outlier, maka mean dan standar deviasi akan lebih baik digunakan untuk mengukur center dan spread dari data tersebut. Karena variabel Year ini mempunyai bentuk skewed, maka untuk menentukan center dan spread akan digunakan mean dan standar deviasi.
#
# Center : Mean variabel Year ini adalah 2006,40 sehingga pusat penyebaran datanya berkisar di tahun 2006.
#
# Spread : Standar deviasi dari variabel Year ini yaitu 5,8. Standar deviasi sendiri digunakan untuk menghitung sebaran dari suatu data yang menunjukkan seberapa jauh data tersebut tersebar dari mean. Untuk menentukan sebarannya, dimulai dari (mean-std) sampai dengan (mean+std). Maka sebaran data dari variabel ini yaitu berkisar dari 2000,2 sampai dengan 2011,8 atau jika dibulatkan berkisar pada tahun 2000 sampai dengan 2012.

# %%
Pf = df['Platform'].value_counts()
plt.pie(Pf, labels=Pf.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x264eaeb9fd0>,
# ...
#  [Text(1.0090946627710826, 0.43786751599874957, 'DS'),
#   Text(0.3699110811084654, 1.0359371564304307, 'PS2'),
#   Text(-0.34352043047852976, 1.0449850304400756, 'PS3'),
#   Text(-0.804216016985179, 0.7504909046913857, 'Wii'),
#   Text(-1.062849965334403, 0.28346066956221394, 'X360'),
#   Text(-1.0762013173654272, -0.22757575552092352, 'PSP'),
#   Text(-0.866045095497049, -0.6782078535121129, 'PS'),
#   Text(-0.5257863074526852, -0.9662032699671796, 'PC'),
#   Text(-0.17600458995835608, -1.0858279717863188, 'XB'),
#   Text(0.16530898705744462, -1.0875076729835251, 'GBA'),
#   Text(0.4401582855384372, -1.00809755662429, 'GC'),
#   Text(0.6330830290448987, -0.8995587131117879, '3DS'),
#   Text(0.7796554882593583, -0.7759750766790527, 'PSV'),
#   Text(0.8814735981903294, -0.658030619115398, 'PS4'),
#   Text(0.9560789631910468, -0.5439788747217423, 'N64'),
#   Text(1.0080974819300759, -0.4401584566110716, 'SNES'),
# ...

# %% [markdown]
# Analisis :
#
# Berbeda dengan variabel kuantitatif, variabel kategorikal sendiri tidak mempunyai distribusi data atau dengan kata lain distribusi data dari variabel kategorikal tidak bisa ditentukan karena tidak adanya five-summary number. Namun, kita bisa melihat dan membaca data dari variabel kategorikal melalui pie chart ataupun bar chart. Berdasarkan pie chart di atas yang memuat data dari variabel Platform, kita bisa melihat bahwa DS merupakan platform yang paling banyak digunakan disusul oleh PS2 dan PS3. Adapun platform yang paling sedikit peminatnya yaitu PCFX. Oleh karena ada beberapa platform yang memiliki sangat sedikit peminat, maka akan lebih baik jika beberapa platform tersebut digabung menjadi satu dengan nama Other/Lainnya agar pie chart tersebut lebih mudah untuk dibaca. Pie chart sendiri sedikit kurang cocok jika digunakan untuk menganalisis variabel kategorikal dengan jumlah data yang banyak seperti ini karena akan menyebabkan pie chart lebih sulit untuk dibaca.

# %%
df['Platform'].value_counts().plot.bar()

# %% [markdown]
# Analisis :
#
# Selain menggunakan pie chart, variabel kategorikal juga bisa dilihat rincian datanya dengan menggunakan bar chart. Oleh karena variabel Platform mempunyai data yang sangat banyak (16000 lebih data) maka bar chart akan lebih cocok untuk digunakan karena data akan terbaca dengan jelas dibandingkan dengan menggunakan pie chart. Dapat dilihat pada bar chart di atas dimana semua data dapat dilihat dan dibaca dengan jelas seperti DS merupakan platform yang paling banyak digunakan menembus angka 2000 disusul oleh PS2 dengan perbedaan yang sangat tipis sekali. Kemudian untuk platform yang paling sedikit digunakan yaitu platform PCFX. Dapat dilihat juga bahwa platform WS, SCD, 3DO, TG16, GG, dan PCFX merupakan platform yang paling sedikit digunakan dengan perbedaan angka yang tidak terlalu signifikan.

# %%
plt.figure(figsize=(5,5))
df['Other_Sales'].plot(kind='density')

# %% [markdown]
# Analisis :
#
# Untuk density saya menggunakan variabel Other_Sales. Density mempunyai fungsi yang kurang lebih sama dengan histogram. Bisa dilihat pada density plot di atas, pusat penyebaran datanya berkisar di angka 0.

# %%
plt.boxplot(df['Other_Sales'], sym="")
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x239701ea2b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x239701ea9a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x239701ddf70>],
#  'medians': [<matplotlib.lines.Line2D at 0x239701f40a0>],
#  'fliers': [],
#  'means': []}

# %% [markdown]
# Analisis :
#
# Box plot digunakan untuk menjelaskan karakteristik dari sebuah variabel kuantitatif. Box plot diatas merupakan box plot tanpa outlier. Box plot sendiri dibedakan menjadi tiga bagian utama yaitu whisker bawah, box dan whisker atas. Whisker bawah merupakan nilai minimum setelah outlier dikeluarkan yang didapat dari Q1 - (1,5 x IQR). Box sendiri terdiri dari tiga garis yaitu garis bawah sebagai kuartil bawah, garis tengah sebagai median, dan garis paling atas sebagai kuartil atas. Adapun whisker atas merupakan nnilai maksimum setelah outlier dikeluarkan yang didapat dari Q3 + (1,5 x IQR). Bisa dilihat dari boxplot diatas bahwa whisker bawahnya memiliki nilai yang sama dengan kuartil bawah yaitu 0. Median berada pada angka 0,01, kuartil atas ada pada angka  0,04, dan whisker atas memiliki rentang dari 0,04 sampai dengan 0,10. Angka yang terletak di bawah whisker bawah atau yang terletak di atas whisker atas akan dianggap sebagai outliers.

# %%
plt.boxplot(df['Other_Sales'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x239703d1df0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x239703de4f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x239703d1a90>],
#  'medians': [<matplotlib.lines.Line2D at 0x239703debb0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x239703deeb0>],
#  'means': []}

# %% [markdown]
# Analisis :
#
# Setelah box plot pada variabel Other_Sales ditampilkan beserta outlier nya, maka dapat dilihat bahwa variabel ini memiliki sangat banyak outlier yang semuanya terletak di atas whisker atas dengan outlier paling jauh berada di atas angka 10.

# %%
dfCatRemove=df.drop('Rank', axis = 1).drop('Year', axis = 1).drop('Name', axis = 1).drop('Platform', axis = 1).drop('Genre', axis = 1).drop('Publisher', axis = 1)
plt.boxplot(dfCatRemove.values,labels=list(dfCatRemove.columns.values), sym = "")
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2397059d910>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2397059dfd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2397059d5b0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x239705a86d0>,
# ...
#  'fliers': [],
#  'means': []}

# %% [markdown]
# Analisis:
#
# Saya mencoba membandingkan variabel Other_Sales dengan variabel kuantitatif lain yang berhubungan dengan penjualan juaga. Dapat dilihat dari perbandingan di atas bahwa baik NA_Sales, EU_Sales, JP_Sales, dan Other_Sales mempunyai rentang whisker bawah dan kuartil bawah yang sama yaitu 0, sedangkan untuk Global_Sales sendiri, whisker bawahnya memiliki rentang dari 0 sampai dengan kuartil bawah yaitu sekitar 0,05. Kemudian JP_Sales dan Other_Sales mempunyai karakteristik data yang hampir sama dimana whisker atasnya memiliki rentang antara 0,04 sampai dengan 0,1, namun yang menjadi sedikit pembeda yaitu bahwa median dari JP_Sales sama dengan kuartil bawahnya yaitu 0. Untuk rentang whisker atas paling lebar dimiliki oleh Global_Sales yang rantangnya antara 0,4 sampai dengan mendekati 1,2. Kemudian disusul oleh NA_Sales yang memiliki rentang whisker atas dari 0,2 sampai dengan 0,6. Adapun semua data yang berada di bawah whisker bawah dari masing-masing box plot atau berada di atas whisker atas dari masing-masing box plot akan dianggap sebagai outliers.

# %%
dfCatRemove=df.drop('Rank', axis = 1).drop('Year', axis = 1).drop('Name', axis = 1).drop('Platform', axis = 1).drop('Genre', axis = 1).drop('Publisher', axis = 1)
plt.boxplot(dfCatRemove.values,labels=list(dfCatRemove.columns.values))
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2397042da00>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2397043c100>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2397042d6a0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x2397043c7c0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x2397043cac0>,
# ...
#  'means': []}

# %% [markdown]
# Analisis :
#
# Box plot di atas merupakan perbandingan variabel kuantitatif yang menyangkut dengan penjualan setelah disertai dengan outliers. Dapat dilihat bahwa semua box plot memiliki outliers di atas nilai maksimus dari whisker atas dan tidak memiliki outlier di bawah nilai minimum dari whisker bawahnya. Outlier terjauh dari NA_Sales berkisar pada angka 40, outlier terjauh dari EU_Sales berkisar di angka 30, outlier terjauh dari JP_Sales dan Other_Sales ada pada sekitar angka 10, dan outlier terjauh dari Global_Sales terletak di atas angka 80. Dapat dilihat juga bahwa outlier pada variabel NA_Sales dan Global_Sales lebih bervariasi dimana setiap outliernya memiliki jarak yang cukup jauh berbanding terbalik dengan JP_Sales dan Other_Sales dimana nilai dari masing-masing outliernya sangat berdekatan.

# %% [markdown]
# # CHAPTER 2.1, 2.2

# %%
plt.scatter(df['Global_Sales'], df['Other_Sales'])
plt.show()

# %% [markdown]
# Analisis :
#
# Scatterplot digunakan untuk menunjukkan hubungan diantara dua variabel kuantitatif. Disini saya menggunakan variabel Global_Sales dan Other_Sales.
#
# Adapun pola keseluruhannya adalah sebagai berikut :
#
# Form : Bentuk dari data di atas yaitu mendekati/hampir linear.
#
# Direction : Karena kenaikan satu variabel diikuti dengan kenaikan variabel yang lain, maka arah dari scatterplot tersebut adalah positif.
#
# Strength : Kekuatan dari suatu scatterplot adalah seberapa dekat data yang ada mengikuti bentuk dari scatterplot itu sendiri. Dapat dilihat dari scatterplot di atas bahwa sebagian data mengikuti bentuknya, namun sebagian lagi tidak, sehingga kekuatan dari scatterplot ini adalah sedang.
#
# Setelah menentukan pola keseluruhan, maka dapa ditentukan pula outliernya. Outlier pada scatterplot sendiri merupakan data yang tidak mengikuti form/bentuk scatterplot itu sendiri. Dapat dilihat dari scatterplot di atas, ada cukup banyak outlier yang menyebar diluar bentuk atau pola scatterplotnya.

# %% [markdown]
# # CHAPTER 2.3, 2.4, 2.5

# %%
x = df["Global_Sales"]
y = df["Other_Sales"]
slope, intercept, r, p, std_err = stats.linregress(x,y)

# %%
print('slope={0}, intercept={1}, r={2}, p={3}, std_err ={4} '.format(slope, intercept, r,p,std_err))
# Out:
# slope=0.09075497355785136, intercept=-0.0007123928379563563, r=0.7483308464078078, p=0.0, std_err =0.0006244560512301647

# %%
def myfunc(x):
  return slope * x + intercept

# %%
mymodel = list(map(myfunc, x))

# %%
plt.scatter(x, y) 
plt.plot(x, mymodel)

# %% [markdown]
# Analisis:
#
# Scatter plot diatas membandingkan dua variabel kuantitatif yaitu Global_Sales dan Other_Sales. Scatter plot digunakan untuk menunjukkan korelasi dan kekuatan antar dua variabel itu sendiri. Pada scatter plot di atas, ditemukan bahwa arahnya yaitu positif (variable Global_Sales dan Other_Sales bertolak belakang). Adapun kekuatan scatter plot tersebut yaitu sedang yang bisa dilihat dari korelasi(r) yang besar yaitu berkisar 0,7.

# %% [markdown]
# # CHAPTER 2.6

# %%
pd.crosstab(df.Platform, df.Genre)
# Out:
# Genre     Action  Adventure  Fighting  Misc  Platform  Puzzle  Racing  \
# Platform
# 2600          61          2         2     5         9      11       6
# 3DO            0          1         0     0         0       1       0
# 3DS          182         37        14    53        28      20      11
# DC             3         11        12     0         2       0       6
# DS           343        240        36   393        92     238      67
# GB             6          5         0     8        19      15       2
# GBA          167         38        23   110       142      41      64
# GC           101         20        42    36        73      13      63
# GEN            3          2         5     1         7       0       1
# GG             0          0         0     0         1       0       0
# N64           38          4        29    18        30      12      57
# NES           13          1         4     2        28      14       4
# ...

# %% [markdown]
# Analisis:
#
# Two way table diatas menunjukkan hubungan antara 2 variabel kategorikal, dalam hal ini Platform dan Genre. Misal, pada tabel di atas bisa dilihat bahwa ada 61 video games yang terjual pada platform 2600 dengan Genre Action.

# %%
pd.crosstab(df.Platform, df.Genre, margins=True, margins_name="Total")
# Out:
# Genre     Action  Adventure  Fighting  Misc  Platform  Puzzle  Racing  \
# Platform
# 2600          61          2         2     5         9      11       6
# 3DO            0          1         0     0         0       1       0
# 3DS          182         37        14    53        28      20      11
# DC             3         11        12     0         2       0       6
# DS           343        240        36   393        92     238      67
# GB             6          5         0     8        19      15       2
# GBA          167         38        23   110       142      41      64
# GC           101         20        42    36        73      13      63
# GEN            3          2         5     1         7       0       1
# GG             0          0         0     0         1       0       0
# N64           38          4        29    18        30      12      57
# NES           13          1         4     2        28      14       4
# ...

# %% [markdown]
# Analisis:
#
# Two way table diatas menunjukkan hubungan antara 2 variabel kategorikal, dalam hal ini Platform dan Genre namun dengan memasukkan total untuk setiap data pada masing-masing variabel. Bisa dilihat total data dari masing-masing variabel adalah 16598 (sesuai dengan banyaknya jumlah data pada data set).

# %%
pd.crosstab(df.Platform, df.Genre, normalize=True, margins=True, margins_name="Total")
# Out:
# Genre       Action  Adventure  Fighting      Misc  Platform    Puzzle  \
# Platform
# 2600      0.003675   0.000120  0.000120  0.000301  0.000542  0.000663
# 3DO       0.000000   0.000060  0.000000  0.000000  0.000000  0.000060
# 3DS       0.010965   0.002229  0.000843  0.003193  0.001687  0.001205
# DC        0.000181   0.000663  0.000723  0.000000  0.000120  0.000000
# DS        0.020665   0.014460  0.002169  0.023678  0.005543  0.014339
# GB        0.000361   0.000301  0.000000  0.000482  0.001145  0.000904
# GBA       0.010061   0.002289  0.001386  0.006627  0.008555  0.002470
# GC        0.006085   0.001205  0.002530  0.002169  0.004398  0.000783
# GEN       0.000181   0.000120  0.000301  0.000060  0.000422  0.000000
# GG        0.000000   0.000000  0.000000  0.000000  0.000060  0.000000
# N64       0.002289   0.000241  0.001747  0.001084  0.001807  0.000723
# NES       0.000783   0.000060  0.000241  0.000120  0.001687  0.000843
# ...

# %% [markdown]
# Analisis:
#
# Two way table di atas menunjukkan perbandingan populasi antar dua variabel kategorikal dengan kesuluruhan data. Misal, terdapat 0,003 video games genre action yang dijual di platform 2600 dari total keseluruhan data yang berjumlah 1.

# %%
pd.crosstab([df.Name,df.Platform], [df.Genre,df.Publisher])
# Out:
# Genre                                                                  Action  \
# Publisher                                        20th Century Fox Video Games
# Name                                    Platform
# '98 Koshien                             PS                                  0
# .hack//G.U. Vol.1//Rebirth              PS2                                 0
# .hack//G.U. Vol.2//Reminisce            PS2                                 0
# .hack//G.U. Vol.2//Reminisce (jp sales) PS2                                 0
# .hack//G.U. Vol.3//Redemption           PS2                                 0
# ...                                                                       ...
# thinkSMART: Chess for Kids              DS                                  0
# uDraw Studio                            Wii                                 0
# uDraw Studio: Instant Artist            Wii                                 0
# ...

# %% [markdown]
# Analisis:
#
# Two way table di atas digunakkan untuk mengelompokkan lebih dari dua variabel kategorikal untuk mengetahui informasi hubungan antar variabel tersebut.
